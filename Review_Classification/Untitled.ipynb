# %%
import tensorflow as tf
import graphviz

# %%
model = tf.keras.models.load_model('drug_review_rnn_50.h5')

# %%
dot_img_file = 'drug_review_rnn_50.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
